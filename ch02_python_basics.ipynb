# %% [markdown]
# ## Ch02  - Python Language Basics, IPython, and Jupyter Notebooks

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
import numpy as np
np.random.seed(12345)
np.set_printoptions(precision=4, suppress=True)

# %%
import numpy as np
data = [np.random.standard_normal() for i in range(7)]
data
# Out:
# [-0.20470765948471295,
#  0.47894333805754824,
#  -0.5194387150567381,
#  -0.55573030434749,
#  1.9657805725027142,
#  1.3934058329729904,
#  0.09290787674371767]

# %%
a = [1, 2, 3]
b = a # a, and b refer to the same object.
b
# Out:
# [1, 2, 3]

# %%
a.append(4)
b
# Out:
# [1, 2, 3, 4]

# %%
def append_elemnt(some_list, element):
    some_list.append(element)

# %%
data = [1, 2, 3]
append_elemnt(data, 4)
data
# Out:
# [1, 2, 3, 4]

# %%
a = 5
type(a)
# Out:
# int

# %%
a = "foo"
type(a)
# Out:
# str

# %%
a = 4.5
b = 2

# String formatiing, to be visited latter
print(f"a is {type(a)}, b is {type(b)}")
# Out:
# a is <class 'float'>, b is <class 'int'>

# %%
a / b
# Out:
# 2.25

# %%
a = 5
isinstance(a, int)
# Out:
# True

# %%
# isinstance can accept a tuple of types if you want to check that an object’s type is among those present in the tuple
a = 5; b = 4.5
isinstance(a, (int, float))
# Out:
# True

# %%
isinstance(b, (int, float))
# Out:
# True

# %%
a = "foo"
getattr(a, "split")
# Out:
# <function str.split(sep=None, maxsplit=-1)>

# %%
def isiterable(obj):
    try:
        iter(obj)
        return True
    except TypeError: # Not iterable
        return False

# %%
isiterable("a string")
# Out:
# True

# %%
isiterable([1, 2, 3])
# Out:
# True

# %%
isiterable(5)
# Out:
# False

# %%
5 - 7
# Out:
# -2

# %%
12 + 21.5
# Out:
# 33.5

# %%
5 <= 2
# Out:
# False

# %%
a = [1, 2, 3]
b = a
c = list(a)

# %%
a is b
# Out:
# True

# %%
a is not c
# Out:
# True

# %%
a == c
# Out:
# True

# %%
a is c
# Out:
# False

# %%
a = None
a is None
# Out:
# True

# %%
# Mutable objects - list, dictionaries, arrays, user defied objects etc
a_list = ["foo", 2, [4, 5]]
a_list[2] = (3, 4)
a_list
# Out:
# ['foo', 2, (3, 4)]

# %%
# Immutable objects - strings, tuples etc
a_tuple = (2, 3, (4, 5))
a_tuple[1] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 # Immutable objects - strings, tuples etc
#       2 a_tuple = (2, 3, (4, 5))
# ----> 3 a_tuple[1] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
ival = 1723458
ival ** 6
# Out:
# 26206210534228818947730475985198919744

# %%
fval = 7.243
fval2 = 6,78e-5

# %%
3 / 2
# Out:
# 1.5

# %%
3 // 2
# Out:
# 1

# %%
a = 'one way of writing a string.'
b = "another way"

# %%
c = """
This is a longer string that
spans multiple lines.
"""

# %%
c.count("\n")
# Out:
# 3

# %%
# strings are immutable
a = "this is a string."
a[10] = 'f'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 # strings are immutable
#       2 a = "this is a string."
# ----> 3 a[10] = 'f'
#
# TypeError: 'str' object does not support item assignment

# %%
b = a.replace('string', 'longer string')
b
# Out:
# 'this is a longer string.'

# %%
a
# Out:
# 'this is a string.'

# %%
a = 5.6
s = str(a)
print(s)
# Out:
# 5.6

# %%
s = "python"
list(s)
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
s[:3]
# Out:
# 'pyt'

# %%
s = "12\\34"
s
# Out:
# '12\\34'

# %%
print(s)
# Out:
# 12\34

# %%
s = r"this\has\no\special\characters"
s
# Out:
# 'this\\has\\no\\special\\characters'

# %%
print(s)
# Out:
# this\has\no\special\characters

# %%
a = "this is the first half "
b = "and this is the second half"
a + b
# Out:
# 'this is the first half and this is the second half'

# %%
template = "{0:.2f} {1:s} are worth US${2:d}."
template.format(88.46, "Argentine Pesos", 1)
# Out:
# '88.46 Argentine Pesos are worth US$1.'

# %%
amount = 10
rate = 88.46
currency = "Pesos"
result = f"{amount} {currency} is woorth US${amount / rate}."
print(result)
# Out:
# 10 Pesos is woorth US$0.11304544426859599.

# %%
result = f"{amount} {currency} is worth US${amount / rate:.2f}."
print(result)
# Out:
# 10 Pesos is worth US$0.11.

# %%
val = "español"
val
# Out:
# 'español'

# %%
val_utf8 = val.encode("utf-8")
val_utf8
# Out:
# b'espa\xc3\xb1ol'

# %%
type(val_utf8)
# Out:
# bytes

# %%
val_utf8.decode("utf-8")
# Out:
# 'español'

# %%
val.encode("latin1")
# Out:
# b'espa\xf1ol'

# %%
val.encode("utf-16")
# Out:
# b'\xff\xfee\x00s\x00p\x00a\x00\xf1\x00o\x00l\x00'

# %%
val.encode("utf-16le")
# Out:
# b'e\x00s\x00p\x00a\x00\xf1\x00o\x00l\x00'
